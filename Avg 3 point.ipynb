# %% [markdown]
# # Analysis of the Top 100 NBA Three Point Percentage Rankings

# %% [markdown]
# #

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import matplotlib.pyplot as plt

# %% [markdown]
# ## Fetching URL and Creating a Data Frame

# %%
url = "https://www.teamrankings.com/nba/player-stat/three-point-field-goal-percentage"

req = requests.get(url)

sopa = BeautifulSoup(req.text, 'lxml')

# %%
# Creating Players List
p = sopa.select("td")[1:500:5]

# %%
p
# Out:
# [<td class="text-left" data-sort="Kennard Luke">
#  <a href="/nba/player/luke-kennard" title="Luke Kennard">Luke Kennard</a>
#  </td>,
#  <td class="text-left" data-sort="Horford Al">
#  <a href="/nba/player/al-horford" title="Al Horford">Al Horford</a>
#  </td>,
#  <td class="text-left" data-sort="Brogdon Malcolm">
#  <a href="/nba/player/malcolm-brogdon" title="Malcolm Brogdon">Malcolm Brogdon</a>
#  </td>,
#  <td class="text-left" data-sort="Lee Damion">
#  <a href="/nba/player/damion-lee" title="Damion Lee">Damion Lee</a>
#  </td>,
#  <td class="text-left" data-sort="Caldwell-Pope Kentavious">
#  <a href="/nba/player/kentavious-caldwell-pope" title="Kentavious Caldwell-Pope">Kentavious Caldwell-Pope</a>
#  </td>,
#  <td class="text-left" data-sort="Joe Isaiah">
#  <a href="/nba/player/isaiah-joe" title="Isaiah Joe">Isaiah Joe</a>
#  </td>,
#  <td class="text-left" data-sort="Curry Stephen">
#  <a href="/nba/player/stephen-curry" title="Stephen Curry">Stephen Curry</a>
#  </td>,
#  <td class="text-left" data-sort="Kispert Corey">
#  <a href="/nba/player/corey-kispert" title="Corey Kispert">Corey Kispert</a>
#  </td>,
#  <td class="text-left" data-sort="Garland Darius">
#  <a href="/nba/player/darius-garland" title="Darius Garland">Darius Garland</a>
#  </td>,
#  <td class="text-left" data-sort="Harris Joe">
#  <a href="/nba/player/joe-harris-2" title="Joe Harris">Joe Harris</a>
#  </td>,
#  <td class="text-left" data-sort="Carter Jevon">
#  <a href="/nba/player/jevon-carter" title="Jevon Carter">Jevon Carter</a>
#  </td>,
#  <td class="text-left" data-sort="Hield Buddy">
#  <a href="/nba/player/buddy-hield" title="Buddy Hield">Buddy Hield</a>
#  </td>,
#  <td class="text-left" data-sort="Leonard Kawhi">
#  <a href="/nba/player/kawhi-leonard" title="Kawhi Leonard">Kawhi Leonard</a>
#  </td>,
#  <td class="text-left" data-sort="Hauser Sam">
#  <a href="/nba/player/sam-hauser" title="Sam Hauser">Sam Hauser</a>
#  </td>,
#  <td class="text-left" data-sort="Burks Alec">
#  <a href="/nba/player/alec-burks" title="Alec Burks">Alec Burks</a>
#  </td>,
#  <td class="text-left" data-sort="Williams Patrick">
#  <a href="/nba/player/patrick-williams-5" title="Patrick Williams">Patrick Williams</a>
#  </td>,
#  <td class="text-left" data-sort="Allen Grayson">
#  <a href="/nba/player/grayson-allen" title="Grayson Allen">Grayson Allen</a>
#  </td>,
#  <td class="text-left" data-sort="Bane Desmond">
#  <a href="/nba/player/desmond-bane" title="Desmond Bane">Desmond Bane</a>
#  </td>,
#  <td class="text-left" data-sort="Bogdanovic Bojan">
#  <a href="/nba/player/bojan-bogdanovic" title="Bojan Bogdanovic">Bojan Bogdanovic</a>
#  </td>,
#  <td class="text-left" data-sort="McDermott Doug">
#  <a href="/nba/player/doug-mcdermott" title="Doug McDermott">Doug McDermott</a>
#  </td>,
#  <td class="text-left" data-sort="Brunson Jalen">
#  <a href="/nba/player/jalen-brunson" title="Jalen Brunson">Jalen Brunson</a>
#  </td>,
#  <td class="text-left" data-sort="DiVincenzo Donte">
#  <a href="/nba/player/donte-divincenzo" title="Donte DiVincenzo">Donte DiVincenzo</a>
#  </td>,
#  <td class="text-left" data-sort="Powell Norman">
#  <a href="/nba/player/norman-powell" title="Norman Powell">Norman Powell</a>
#  </td>,
#  <td class="text-left" data-sort="Porter Jr. Michael">
#  <a href="/nba/player/michael-porter-jr" title="Michael Porter Jr.">Michael Porter Jr.</a>
#  </td>,
#  <td class="text-left" data-sort="Murray Keegan">
#  <a href="/nba/player/keegan-murray" title="Keegan Murray">Keegan Murray</a>
#  </td>,
#  <td class="text-left" data-sort="Thompson Klay">
#  <a href="/nba/player/klay-thompson" title="Klay Thompson">Klay Thompson</a>
#  </td>,
#  <td class="text-left" data-sort="Markkanen Lauri">
#  <a href="/nba/player/lauri-markkanen" title="Lauri Markkanen">Lauri Markkanen</a>
#  </td>,
#  <td class="text-left" data-sort="Niang Georges">
#  <a href="/nba/player/georges-niang" title="Georges Niang">Georges Niang</a>
#  </td>,
#  <td class="text-left" data-sort="Haliburton Tyrese">
#  <a href="/nba/player/tyrese-haliburton" title="Tyrese Haliburton">Tyrese Haliburton</a>
#  </td>,
#  <td class="text-left" data-sort="Maxey Tyrese">
#  <a href="/nba/player/tyrese-maxey" title="Tyrese Maxey">Tyrese Maxey</a>
#  </td>,
#  <td class="text-left" data-sort="Morris Monte">
#  <a href="/nba/player/monte-morris" title="Monte Morris">Monte Morris</a>
#  </td>,
#  <td class="text-left" data-sort="Bogdanovic Bogdan">
#  <a href="/nba/player/bogdan-bogdanovic" title="Bogdan Bogdanovic">Bogdan Bogdanovic</a>
#  </td>,
#  <td class="text-left" data-sort="Williams Grant">
#  <a href="/nba/player/grant-williams-5" title="Grant Williams">Grant Williams</a>
#  </td>,
#  <td class="text-left" data-sort="Bridges Mikal">
#  <a href="/nba/player/mikal-bridges" title="Mikal Bridges">Mikal Bridges</a>
#  </td>,
#  <td class="text-left" data-sort="Grant Jerami">
#  <a href="/nba/player/jerami-grant" title="Jerami Grant">Jerami Grant</a>
#  </td>,
#  <td class="text-left" data-sort="Huerter Kevin">
#  <a href="/nba/player/kevin-huerter" title="Kevin Huerter">Kevin Huerter</a>
#  </td>,
#  <td class="text-left" data-sort="Johnson Cameron">
#  <a href="/nba/player/cameron-johnson-5" title="Cameron Johnson">Cameron Johnson</a>
#  </td>,
#  <td class="text-left" data-sort="Craig Torrey">
#  <td class="text-left" data-sort="Graham Devonte'">
#  <a href="/nba/player/devonte-graham" title="Devonte' Graham">Devonte' Graham</a>
#  </td>,
#  <td class="text-left" data-sort="Grimes Quentin">
#  <a href="/nba/player/quentin-grimes" title="Quentin Grimes">Quentin Grimes</a>
#  </td>]

# %%
# Cleaning up players list
players = []

for x in p:
    player = x.text.replace('\n', '').replace("'", '')
    
    players.append(player)

# %%
players
# Out:
# ['Luke Kennard',
#  'Al Horford',
#  'Malcolm Brogdon',
#  'Damion Lee',
#  'Kentavious Caldwell-Pope',
#  'Isaiah Joe',
#  'Stephen Curry',
#  'Corey Kispert',
#  'Darius Garland',
#  'Joe Harris',
#  'Jevon Carter',
#  'Buddy Hield',
#  'Kawhi Leonard',
#  'Sam Hauser',
#  'Alec Burks',
#  'Patrick Williams',
#  'Grayson Allen',
#  'Desmond Bane',
#  'Bojan Bogdanovic',
#  'Doug McDermott',
#  'Jalen Brunson',
#  'Donte DiVincenzo',
#  'Norman Powell',
#  'Michael Porter Jr.',
#  'Keegan Murray',
#  'Klay Thompson',
#  'Lauri Markkanen',
#  'Georges Niang',
#  'Tyrese Haliburton',
#  'Tyrese Maxey',
#  'Monte Morris',
#  'Bogdan Bogdanovic',
#  'Grant Williams',
#  'Mikal Bridges',
#  'Jerami Grant',
#  'Kevin Huerter',
#  'Cameron Johnson',
#  'Torrey Craig',
#  'James Harden',
#  'Kelly Olynyk',
#  'DeAnthony Melton',
#  'Andrew Wiggins',
#  'Devin Vassell',
#  'Seth Curry',
#  'Royce ONeale',
#  'Trey Murphy III',
#  'Spencer Dinwiddie',
#  'DAngelo Russell',
#  'Jamal Murray',
#  'Myles Turner',
#  'Kristaps Porzingis',
#  'Jaden McDaniels',
#  'Kevin Durant',
#  'Jrue Holiday',
#  'AJ Griffin',
#  'Mike Muscala',
#  'Zach LaVine',
#  'Donovan Mitchell',
#  'Tyus Jones',
#  'Terrence Ross',
#  'Nicolas Batum',
#  'Tobias Harris',
#  'Brook Lopez',
#  'Kyrie Irving',
#  'Tim Hardaway Jr.',
#  'Chris Paul',
#  'CJ McCollum',
#  'Anthony Lamb',
#  'Anfernee Simons',
#  'Reggie Bullock',
#  'Bruce Brown',
#  'Troy Brown Jr.',
#  'LaMelo Ball',
#  'Paul George',
#  'Tyler Herro',
#  'Damian Lillard',
#  'Harrison Barnes',
#  'Caleb Martin',
#  'Trey Lyles',
#  'Derrick White',
#  'Terence Davis',
#  'Bones Hyland',
#  'Franz Wagner',
#  'Devin Booker',
#  'Marcus Morris Sr.',
#  'Bradley Beal',
#  'Christian Wood',
#  'Anthony Edwards',
#  'Gary Trent Jr.',
#  'Mike Conley',
#  'Lonnie Walker IV',
#  'Immanuel Quickley',
#  'DeAndre Hunter',
#  'O.G. Anunoby',
#  'Dejounte Murray',
#  'Saddiq Bey',
#  'Santi Aldama',
#  'Caris LeVert',
#  'Devonte Graham',
#  'Quentin Grimes']

# %%
# Create teams list
t = sopa.select("td")[2:500:5]

# %%
# Clean up teams list
teams = []

for x in t:
    
    teams.append(x.text)

# %%
teams
# Out:
# ['Memphis Grizzlies',
#  'Boston Celtics',
#  'Boston Celtics',
#  'Phoenix Suns',
#  'Denver Nuggets',
#  'Oklahoma City Thunder',
#  'Golden State Warriors',
#  'Washington Wizards',
#  'Cleveland Cavaliers',
#  'Brooklyn Nets',
#  'Milwaukee Bucks',
#  'Indiana Pacers',
#  'Los Angeles Clippers',
#  'Boston Celtics',
#  'Detroit Pistons',
#  'Chicago Bulls',
#  'Milwaukee Bucks',
#  'Memphis Grizzlies',
#  'Detroit Pistons',
#  'San Antonio Spurs',
#  'New York Knicks',
#  'Golden State Warriors',
#  'Los Angeles Clippers',
#  'Denver Nuggets',
#  'Sacramento Kings',
#  'Golden State Warriors',
#  'Utah Jazz',
#  'Philadelphia 76ers',
#  'Indiana Pacers',
#  'Philadelphia 76ers',
#  'Washington Wizards',
#  'Atlanta Hawks',
#  'Boston Celtics',
#  'Brooklyn Nets',
#  'Portland Trail Blazers',
#  'Sacramento Kings',
#  'Brooklyn Nets',
#  'Phoenix Suns',
#  'Philadelphia 76ers',
#  'Utah Jazz',
#  'Philadelphia 76ers',
#  'Golden State Warriors',
#  'San Antonio Spurs',
#  'Brooklyn Nets',
#  'Brooklyn Nets',
#  'New Orleans Pelicans',
#  'Brooklyn Nets',
#  'Los Angeles Lakers',
#  'Denver Nuggets',
#  'Indiana Pacers',
#  'Washington Wizards',
#  'Minnesota Timberwolves',
#  'Phoenix Suns',
#  'Milwaukee Bucks',
#  'Atlanta Hawks',
#  'Boston Celtics',
#  'Chicago Bulls',
#  'Cleveland Cavaliers',
#  'Memphis Grizzlies',
#  'Phoenix Suns',
#  'Los Angeles Clippers',
#  'Philadelphia 76ers',
#  'Milwaukee Bucks',
#  'Dallas Mavericks',
#  'Dallas Mavericks',
#  'Phoenix Suns',
#  'New Orleans Pelicans',
#  'Golden State Warriors',
#  'Portland Trail Blazers',
#  'Dallas Mavericks',
#  'Denver Nuggets',
#  'Los Angeles Lakers',
#  'Charlotte Hornets',
#  'Los Angeles Clippers',
#  'Miami Heat',
#  'Portland Trail Blazers',
#  'Sacramento Kings',
#  'Miami Heat',
#  'Sacramento Kings',
#  'Boston Celtics',
#  'Sacramento Kings',
#  'Los Angeles Clippers',
#  'Orlando Magic',
#  'Phoenix Suns',
#  'Los Angeles Clippers',
#  'Washington Wizards',
#  'Dallas Mavericks',
#  'Minnesota Timberwolves',
#  'Toronto Raptors',
#  'Minnesota Timberwolves',
#  'Los Angeles Lakers',
#  'New York Knicks',
#  'Atlanta Hawks',
#  'Toronto Raptors',
#  'Atlanta Hawks',
#  'Atlanta Hawks',
#  'Memphis Grizzlies',
#  'Cleveland Cavaliers',
#  'San Antonio Spurs',
#  'New York Knicks']

# %%
# Create position list 
pos = sopa.select("td")[3:500:5]

# %%
# Clean up position list
position = []

for p in pos:
    
    position.append(p.text)

# %%
position
# Out:
# ['SG',
#  'C',
#  'SG',
#  'SG',
#  'SG',
#  'PG',
#  'PG',
#  'SF',
#  'PG',
#  'SG',
#  'PG',
#  'SG',
#  'SF',
#  'SF',
#  'SG',
#  'SF',
#  'SG',
#  'SG',
#  'SF',
#  'SF',
#  'PG',
#  'SG',
#  'SG',
#  'PF',
#  'SF',
#  'SG',
#  'PF',
#  'SF',
#  'PG',
#  'PG',
#  'PG',
#  'SG',
#  'PF',
#  'SF',
#  'SF',
#  'SG',
#  'PF',
#  'SF',
#  'SG',
#  'PF',
#  'PG',
#  'SF',
#  'SG',
#  'SG',
#  'SF',
#  'SF',
#  'PG',
#  'PG',
#  'SG',
#  'C',
#  'PF',
#  'SF',
#  'SF',
#  'PG',
#  'SF',
#  'PF',
#  'PG',
#  'SG',
#  'PG',
#  'SG',
#  'SG',
#  'SF',
#  'C',
#  'PG',
#  'SG',
#  'PG',
#  'SG',
#  'SF',
#  'SG',
#  'SG',
#  'PG',
#  'SG',
#  'PG',
#  'SF',
#  'SG',
#  'PG',
#  'SF',
#  'SF',
#  'PF',
#  'PG',
#  'SG',
#  'PG',
#  'SF',
#  'SG',
#  'PF',
#  'SG',
#  'PF',
#  'SG',
#  'SG',
#  'PG',
#  'SG',
#  'SG',
#  'PF',
#  'SF',
#  'PG',
#  'SF',
#  'PF',
#  'SG',
#  'PG',
#  'SG']

# %%
# Create Value list
v = sopa.select("td")[4:500:5]

# %%
# Clean up value list
values = []

for x in v:
    
    values.append(x.text)

# %%
values
# Out:
# ['45.7%',
#  '45.4%',
#  '45.2%',
#  '44.4%',
#  '44.0%',
#  '44.0%',
#  '43.3%',
#  '43.1%',
#  '43.0%',
#  '43.0%',
#  '42.9%',
#  '42.7%',
#  '41.7%',
#  '41.5%',
#  '41.4%',
#  '41.4%',
#  '41.2%',
#  '41.1%',
#  '41.1%',
#  '41.1%',
#  '41.1%',
#  '41.0%',
#  '41.0%',
#  '41.0%',
#  '40.9%',
#  '40.8%',
#  '40.8%',
#  '40.8%',
#  '40.7%',
#  '40.7%',
#  '40.5%',
#  '40.4%',
#  '40.4%',
#  '40.3%',
#  '40.3%',
#  '40.1%',
#  '40.1%',
#  '40.1%',
#  '40.1%',
#  '39.7%',
#  '39.6%',
#  '39.6%',
#  '39.4%',
#  '39.4%',
#  '39.1%',
#  '38.9%',
#  '38.9%',
#  '38.9%',
#  '38.9%',
#  '38.8%',
#  '38.7%',
#  '38.7%',
#  '38.6%',
#  '38.6%',
#  '38.4%',
#  '38.4%',
#  '38.4%',
#  '38.3%',
#  '38.3%',
#  '38.3%',
#  '38.3%',
#  '38.2%',
#  '38.2%',
#  '38.2%',
#  '38.1%',
#  '38.0%',
#  '38.0%',
#  '37.9%',
#  '37.8%',
#  '37.8%',
#  '37.7%',
#  '37.6%',
#  '37.6%',
#  '37.6%',
#  '37.5%',
#  '37.5%',
#  '37.5%',
#  '37.4%',
#  '37.4%',
#  '37.2%',
#  '37.1%',
#  '37.1%',
#  '37.0%',
#  '37.0%',
#  '36.9%',
#  '36.9%',
#  '36.9%',
#  '36.9%',
#  '36.8%',
#  '36.5%',
#  '36.5%',
#  '36.4%',
#  '36.3%',
#  '36.2%',
#  '36.2%',
#  '36.1%',
#  '36.0%',
#  '35.9%',
#  '35.7%',
#  '35.7%']

# %%
# Create a data frame from dictionary vaules attached to a variable
p_dict = {"Player": players, "Team": teams, "Position": position, "Value": values}

df = pd.DataFrame(p_dict)

#convert data frame into a CSV file
df.to_csv("NBA_3point_%_list")

# %%
# Read CSV file
data = pd.read_csv("NBA_3point_%_list")

# %%
data
# Out:
#     Unnamed: 0                    Player                 Team Position  Value
# 0            0              Luke Kennard    Memphis Grizzlies       SG  45.7%
# 1            1                Al Horford       Boston Celtics        C  45.4%
# 2            2           Malcolm Brogdon       Boston Celtics       SG  45.2%
# 3            3                Damion Lee         Phoenix Suns       SG  44.4%
# 4            4  Kentavious Caldwell-Pope       Denver Nuggets       SG  44.0%
# ..         ...                       ...                  ...      ...    ...
# 95          95                Saddiq Bey        Atlanta Hawks       SF  36.1%
# 96          96              Santi Aldama    Memphis Grizzlies       PF  36.0%
# 97          97              Caris LeVert  Cleveland Cavaliers       SG  35.9%
# 98          98            Devonte Graham    San Antonio Spurs       PG  35.7%
# 99          99            Quentin Grimes      New York Knicks       SG  35.7%
#
# [100 rows x 5 columns]

# %%
# Check the position column in my Data Frame
data["Position"]
# Out:
# 0     SG
# 1      C
# 2     SG
# 3     SG
# 4     SG
#       ..
# 95    SF
# 96    PF
# 97    SG
# 98    PG
# 99    SG
# Name: Position, Length: 100, dtype: object

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ## Analyze number of Players By Position in NBA 3 Point Percentage Data Frame

# %%
# Count the number of values in each position
position_counts = data['Position'].value_counts()

# Print the number of players by position
for position, count in position_counts.items():
    print(f"Number of players in {position} position is {count}")

# Create a bar chart of the position counts
fig, ax = plt.subplots(figsize=(12,10))
position_counts.plot(kind='bar', ax=ax)

# Set the chart title and axis labels
plt.title('Number of Players by Position')
plt.xlabel('Position')
plt.ylabel('Number of Players')

# Add visible lines for each number on the y axis
ax.yaxis.grid(True)

# Display the chart
plt.show()
# Out:
# Number of players in SG position is 36
# Number of players in SF position is 25
# Number of players in PG position is 24
# Number of players in PF position is 12
# Number of players in C position is 3

# %% [markdown]
# ### By Far Shooting Guards account for most of the players by position. Centers account for the least amount of Players by position.

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ## Convert Each Value in the data[Value] column into a Float to find the mean.
#
# ## Average Value By Position

# %%
# Convert 'Value' to string, then remove the percent sign and convert to float
data['Value'] = data['Value'].astype(str).str.replace('%', '').astype(float)

# Group the dataframe by 'Position' and calculate the mean of 'Value' for each group
position_means = data.groupby('Position')['Value'].mean()

# Sort the position means dictionary in descending order
position_means_sorted = dict(sorted(position_means.items(), key=lambda item: item[1], reverse=True))

# Print the average value by position in descending order
for position, mean in position_means_sorted.items():
    print(f"Average value by {position} position is {mean:.2f}")

# Create a bar chart of the position means in descending order
fig, ax = plt.subplots(figsize=(12,10))
pd.Series(position_means_sorted).plot(kind='barh', ax=ax)

# Set the chart title and axis labels
plt.title('Average Value by Position')
plt.xlabel('Position')
plt.ylabel('Average Value')

# Add visible lines for each number on the x axis
ax.xaxis.grid(True)


# Display the chart
plt.show()
# Out:
# Average value by C position is 40.80
# Average value by SG position is 39.46
# Average value by SF position is 39.34
# Average value by PG position is 39.19
# Average value by PF position is 38.55

# %% [markdown]
# ### Although Centers account for the fewest players by position. They have the highest Average by Position.

# %%
# Attach the overall mean of the data Frame to a variable
overall_avg = data['Value'].mean()

# %%
# Overall Mean
overall_avg
# Out:
# 39.278

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ## Visualize how many players in this Data Frame are in the Eastern Conference compared to The Western Conference

# %%
# Create a list of East conference teams and West conference teams
east_teams = ['Atlanta Hawks', 'Boston Celtics', 'Brooklyn Nets', 'Charlotte Hornets', 'Chicago Bulls', 'Cleveland Cavaliers', 'Detroit Pistons', 'Indiana Pacers', 'Miami Heat', 'Milwaukee Bucks', 'New York Knicks', 'Orlando Magic', 'Philadelphia 76ers', 'Toronto Raptors', 'Washington Wizards']
west_teams = ['Dallas Mavericks', 'Denver Nuggets', 'Golden State Warriors', 'Houston Rockets', 'Los Angeles Clippers', 'Los Angeles Lakers', 'Memphis Grizzlies', 'Minnesota Timberwolves', 'New Orleans Pelicans', 'Oklahoma City Thunder', 'Phoenix Suns', 'Portland Trail Blazers', 'Sacramento Kings', 'San Antonio Spurs', 'Utah Jazz']

# Count the number of East and West conference teams in the dataframe
east_count = data['Team'].isin(east_teams).sum()
west_count = data['Team'].isin(west_teams).sum()

# Set the figure size
plt.figure(figsize=(8, 6))

# Create a pie chart of the team counts by conference
labels = ['East', 'West']
counts = [east_count, west_count]
plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90)

# Add player count text to the plot
plt.text(0.5, 1.15, f'East: {east_count} players\nWest: {west_count} players', ha='center', va='center', transform=plt.gca().transAxes)

# Set the chart title and legend
plt.title('NBA Team Counts by Conference')
plt.legend(title='Conference', loc='best')

# Display the chart
plt.show()

# %% [markdown]
# ### The Western Conference acounts for more players in the Data Frame.

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ## How Many Players From each NBA team are present in the Data Frame

# %%
# Count the number of players on each team
team_counts = data['Team'].value_counts()

# Get the teams with the most players
most_players_teams = list(team_counts.head(4).index)

# Print the teams with the most players
print("The teams with the most players are:")
for team in most_players_teams:
    print(f"- {team} ({team_counts[team]} players)")

# Create a bar chart of the team counts
fig, ax = plt.subplots(figsize=(14,12)) # Increase the size of the chart
team_counts.plot(kind='barh', ax=ax) # Set the chart to use the ax instance

# Set the chart title and axis labels
ax.set_title('NBA Team Player Counts') # Use the ax instance to set the title
ax.set_xlabel('Team')
ax.set_ylabel('Player Count')

# Display the chart
plt.show()
# Out:
# The teams with the most players are:
# - Phoenix Suns (6 players)
# - Brooklyn Nets (6 players)
# - Los Angeles Clippers (6 players)
# - Boston Celtics (6 players)
